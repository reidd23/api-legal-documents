# %% [markdown]
# <a href="https://colab.research.google.com/github/reidd23/api-legal-documents/blob/main/RayVentura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📦 Install ImageMagick and ffmpeg
# !sudo apt-get install ffmpeg

import os

if not os.path.exists('/content/ShortGPT'):
  # 📂 Clone the ShortGPT repository
  # !git clone https://github.com/RayVentura/ShortGPT.git
  # %cd /content/ShortGPT/
else:
  # %cd /content/ShortGPT/
  # If the directory already exists, just pull the latest version
  # !git pull
# 🚀 Change directory to ShortGPT

# 🛠️ Install required Python packages
# !pip install -r requirements.txt
# !python runShortGPTColab.py
